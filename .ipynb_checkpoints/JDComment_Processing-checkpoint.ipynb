# %% [markdown]
# ### 数据清洗

# %%
#读取数据库数据
import pandas as pd
from pandas import DataFrame as df
Comment_data = pd.read_csv('data/JDComment_data.csv')  # 读取训练数据

# %%
Comment_data[Comment_data['评论内容'] == '此用户未填写评价内容' ]#查看评论前几行数据
# Out:
#               用户ID        评论内容        会员级别  点赞数  回复数  得分                 购买时间  \
# 3985   12512647810  此用户未填写评价内容        铜牌会员    0    0   5  2019-03-05 15:44:19
# 4002   12511539300  此用户未填写评价内容        金牌会员    0    0   5  2019-03-05 10:29:41
# 4016   12510642159  此用户未填写评价内容        注册会员    0    0   5  2019-03-04 22:32:15
# 4019   12510365973  此用户未填写评价内容        金牌会员    0    0   5  2019-03-04 21:05:51
# 4059   12507908284  此用户未填写评价内容        银牌会员    0    0   5  2019-03-04 09:28:01
# 4079   12506443899  此用户未填写评价内容      PLUS会员    0    0   5  2019-03-03 18:22:05
# 4085   12505863015  此用户未填写评价内容        注册会员    0    0   5  2019-03-03 15:28:28
# 4138   12503963100  此用户未填写评价内容      PLUS会员    0    0   3  2019-03-02 22:14:36
# 4150   12503323293  此用户未填写评价内容        银牌会员    0    0   5  2019-03-02 18:49:40
# 4193   12501730345  此用户未填写评价内容        银牌会员    0    0   5  2019-03-02 10:51:11
# 4198   12501621470  此用户未填写评价内容      PLUS会员    0    0   5  2019-03-02 10:22:18
# 4223   12500373334  此用户未填写评价内容        注册会员    0    0   1  2019-03-01 20:10:43
# 4230   12499846592  此用户未填写评价内容        金牌会员    0    0   5  2019-03-01 17:20:50
# 4259   12498463528  此用户未填写评价内容        银牌会员    0    0   5  2019-03-01 10:27:22
# 4270   12497661916  此用户未填写评价内容        银牌会员    0    0   3  2019-02-28 22:51:40
# 4297   12496614190  此用户未填写评价内容        金牌会员    0    0   5  2019-02-28 17:11:22
# 4308   12496073379  此用户未填写评价内容        银牌会员    0    0   5  2019-02-28 14:26:02
# 4326   12495626323  此用户未填写评价内容        注册会员    0    0   5  2019-02-28 12:07:22
# 4350   12494713311  此用户未填写评价内容  PLUS会员[试用]    0    0   5  2019-02-28 04:34:43
# 4356   12494103125  此用户未填写评价内容        金牌会员    2    0   5  2019-02-27 20:42:12
# 4358   12494033160  此用户未填写评价内容        铜牌会员    0    0   5  2019-02-27 20:19:50
# 4380   12492602153  此用户未填写评价内容        注册会员    0    0   5  2019-02-27 12:50:18
# 4383   12492325826  此用户未填写评价内容        注册会员    0    0   5  2019-02-27 11:26:18
# 4392   12491902983  此用户未填写评价内容        注册会员    0    0   5  2019-02-27 09:32:34
# 4406   12491341929  此用户未填写评价内容        钻石会员    1    0   5  2019-02-26 22:58:05
# 4451   12507613386  此用户未填写评价内容        钻石会员    0    0   5  2019-03-04 07:12:48
# 4453   12506858021  此用户未填写评价内容        铜牌会员    0    0   5  2019-03-03 20:31:07
# 4454   12506463940  此用户未填写评价内容        注册会员    0    0   5  2019-03-03 18:27:33
# 4459   12503590022  此用户未填写评价内容  PLUS会员[试用]    0    0   5  2019-03-02 20:13:56
# 4460   12502670744  此用户未填写评价内容        铜牌会员    0    0   5  2019-03-02 15:31:24
# ...            ...         ...         ...  ...  ...  ..                  ...
# 21281  12489812911  此用户未填写评价内容        铜牌会员    0    3   5  2019-02-26 14:56:06
# 21314  12480979132  此用户未填写评价内容        铜牌会员    0    0   5  2019-02-23 18:12:31
# 21322  12479983659  此用户未填写评价内容        铜牌会员    0    0   5  2019-02-23 12:55:20
# 21336  12477120440  此用户未填写评价内容        注册会员    0    0   5  2019-02-22 14:01:11
# 21339  12476622619  此用户未填写评价内容        银牌会员    0    0   5  2019-02-22 11:41:25
# 21340  12476586486  此用户未填写评价内容        银牌会员    0    0   5  2019-02-22 11:31:55
# 21341  12476061434  此用户未填写评价内容        注册会员    0    0   5  2019-02-22 09:22:21
# 21364  12469407179  此用户未填写评价内容      PLUS会员    0    0   5  2019-02-20 11:39:25
# 21388  12463806819  此用户未填写评价内容        注册会员    0    0   5  2019-02-18 14:48:17
# 21393  12463010551  此用户未填写评价内容        金牌会员    0    0   5  2019-02-18 11:01:05
# 21406  12459296362  此用户未填写评价内容        注册会员    0    0   5  2019-02-17 00:12:46
# 21415  12458062851  此用户未填写评价内容        注册会员    0    0   5  2019-02-16 16:40:30
# 21420  12457401326  此用户未填写评价内容        金牌会员    0    0   5  2019-02-16 12:58:07
# 21432  12454929661  此用户未填写评价内容        金牌会员    0    0   5  2019-02-15 14:43:26
# 21435  12454435350  此用户未填写评价内容  PLUS会员[试用]    0    0   5  2019-02-15 11:53:19
# 21477  12445385665  此用户未填写评价内容        钻石会员    0    0   5  2019-02-11 16:27:24
# 21517  12440886522  此用户未填写评价内容      PLUS会员    0    1   5  2019-02-08 22:27:38
# 21526  12438724077  此用户未填写评价内容        铜牌会员    0    0   5  2019-02-06 22:56:44
# 21548  12434815282  此用户未填写评价内容      PLUS会员    0    0   5  2019-02-03 11:27:13
# 21578  12427204783  此用户未填写评价内容        金牌会员    2    0   5  2019-01-30 22:25:38
# 21584  12426220053  此用户未填写评价内容        铜牌会员    0    0   5  2019-01-30 16:37:35
# 21586  12425417926  此用户未填写评价内容        银牌会员    0    0   5  2019-01-30 11:50:10
# 21636  12412565973  此用户未填写评价内容      PLUS会员    0    0   5  2019-01-26 12:12:23
# 21643  12410823020  此用户未填写评价内容        银牌会员    0    0   5  2019-01-25 20:16:27
# 21650  12408914055  此用户未填写评价内容        钻石会员    0    0   5  2019-01-25 10:49:14
# 21662  12405665157  此用户未填写评价内容        铜牌会员    0    0   5  2019-01-24 11:33:20
# 21672  12402941862  此用户未填写评价内容        银牌会员    0    0   5  2019-01-23 15:13:28
# 21674  12402597927  此用户未填写评价内容        银牌会员    0    0   5  2019-01-23 13:36:50
# 21698  12397649891  此用户未填写评价内容        金牌会员    0    0   5  2019-01-22 00:38:15
# 21708  12392642426  此用户未填写评价内容        金牌会员    0    0   5  2019-01-20 17:24:57
#
#                                                   手机型号
# 3985   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4002   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4016   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4019   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4059   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4079   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4085   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4138   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4150   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4193   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4198   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4223   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4230   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4259   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4270   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4297   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4308   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4326   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4350   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4356   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4358   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4380   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4383   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4392   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4406   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4451   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4453   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4454   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4459   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# 4460   Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机
# ...                                                ...
# 21281       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21314       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21322       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21336       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21339       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21340       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21341       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21364       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21388       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21393       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21406       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21415       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21420       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21432       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21435       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21477       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21517       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21526       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21548       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21578       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21584       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21586       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21636       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21643       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21650       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21662       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21672       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21674       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21698       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
# 21708       Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机
#
# [625 rows x 8 columns]

# %% [markdown]
# 填充缺省值以及删除第一行

# %%
Comment_data.drop(index=0,axis=0) #删除第一行
Comment_data.isnull().any()#查看哪些列存在空值
# Out:
# 用户ID    False
# 评论内容    False
# 会员级别    False
# 点赞数     False
# 回复数     False
# 得分      False
# 购买时间    False
# 手机型号    False
# dtype: bool

# %%
#Comment_data[Comment_data.isnull().values==True]
for col in Comment_data:
    if col == "会员级别" or col == "评论内容":
        Comment_data[col].fillna('', inplace=True)
    elif col == "用户ID":
        Comment_data[col].fillna('00000000000', inplace=True)
    else:
        Comment_data[col].fillna(0, inplace=True)
Comment_data.isnull().any()#查看是否进行了填充
# Out:
# 用户ID    False
# 评论内容    False
# 会员级别    False
# 点赞数     False
# 回复数     False
# 得分      False
# 购买时间    False
# 手机型号    False
# dtype: bool

# %% [markdown]
# (DataFrame筛选数据与loc用法)[https://blog.csdn.net/junbujianwpl/article/details/70473659]

# %%
#Comment_data[Comment_data.评论内容.duplicated()].count()
#print(Comment_data[Comment_data.评论内容.duplicated()].count())	# 最后两项重复
#print(len(Comment_data[Comment_data.评论内容 == '此用户未填写评价内容']))
Comment_data[Comment_data['评论内容']=="此用户未填写评价内容"] = ""#清空未评价信息
print(len(Comment_data[Comment_data['评论内容']!=""])) #统计有效评论数
# Out:
# 21091

# %% [markdown]
# ## 数据可视化及分析
# ### 会员等级编码

# %%
from numpy import array
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
# 会员等级分类
data = Comment_data[Comment_data['会员级别']!='']
value1 = array(data['会员级别'])
phone_type = Comment_data[Comment_data['手机型号']!='']
value2 = array(data['手机型号'])
#print(values)
# 手机型号分类
#整数编码
level_encoder = LabelEncoder()
phone_type_encode = LabelEncoder()
integer_level_encoded = level_encoder.fit_transform(value1)
integer_type_encoded = phone_type_encode.fit_transform(value2)
#print(label_encoder.get_params(False))
print(integer_level_encoded)
userLevel = level_encoder.classes_
print(level_encoder.classes_)
print(integer_type_encoded)
phone_type = phone_type_encode.classes_
print(phone_type_encode.classes_)
# Out:
# [6 0 0 ... 5 7 0]
# ['PLUS会员' 'PLUS会员[试用]' '企业会员' '注册会员' '金牌会员' '钻石会员' '铜牌会员' '银牌会员']
# [0 0 0 ... 3 3 3]
# ['Apple iPhone 8 Plus (A1864) 256GB 金色 移动联通电信4G手机'
#  'Apple iPhone 8 Plus (A1864) 256GB 银色 移动联通电信4G手机'
#  'Apple iPhone 8 Plus (A1864) 64GB 深空灰色 移动联通电信4G手机'
#  'Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机']

# %% [markdown]
# ### 购买时间处理

# %%
hourList = []
month = []
year = []
useLessData = 0
for i in Comment_data['购买时间']:
    try:
        #print(str(i))
        hourList.append(str(i).split(' ')[1].split(':')[0])
        month.append(str(i).split(' ')[0].split('-')[1])
        year.append(str(i).split(' ')[0].split('-')[0])
    except:
        useLessData += 1
print('无效数据有%s条'%useLessData)
phone_year_encode = LabelEncoder()
year_encoded = phone_year_encode.fit_transform(year)
print(phone_year_encode.classes_)
print(year_encoded)
# Out:
# 无效数据有0条
# ['2017' '2018' '2019']
# [2 1 2 ... 2 2 2]
# ['21', '09', '09', '23', '17', '14', '11', '10', '20', '16', '17', '15', '23', '11', '15', '15', '07', '22', '18', '11', '21', '15', '15', '22', '12', '22', '21', '18', '15', '21', '15', '15', '22', '10', '21', '17', '21', '16', '18', '15', '11', '14', '00', '12', '20', '09', '21', '15', '21', '12', '23', '12', '19', '20', '09', '14', '06', '12', '10', '00', '18', '12', '14', '17', '11', '21', '12', '11', '20', '15', '10', '11', '22', '16', '10', '08', '14', '20', '22', '07', '22', '12', '23', '20', '13', '09', '15', '19', '09', '22', '07', '00', '13', '23', '12', '20', '01', '20', '12', '09', '10', '23', '19', '22', '21', '23', '18', '08', '10', '09', '00', '09', '15', '21', '20', '09', '15', '23', '00', '12', '11', '14', '10', '10', '17', '17', '22', '19', '21', '10', '22', '17', '07', '17', '15', '16', '09', '16', '14', '10', '10', '15', '23', '10', '20', '13', '16', '12', '09', '16', '10', '20', '12', '14', '12', '22', '23', '14', '13', '21', '08', '14', '23', '12', '15', '16', '09', '11', '17', '09', '14', '11', '13', '10', '14', '08', '22', '12', '21', '19', '22', '12', '13', '01', '15', '18', '14', '12', '11', '01', '17', '22', '10', '21', '07', '20', '22', '10', '16', '09', '22', '20', '12', '13', '08', '17', '21', '20', '10', '22', '18', '23', '21', '16', '21', '13', '15', '15', '09', '19', '15', '13', '18', '17', '08', '04', '14', '11', '09', '15', '11', '12', '22', '09', '14', '19', '10', '12', '15', '08', '18', '22', '21', '13', '16', '19', '15', '10', '12', '22', '08', '09', '01', '09', '10', '10', '01', '16', '15', '07', '12', '13', '12', '18', '17', '21', '09', '23', '17', '15', '14', '19', '20', '23', '22', '03', '12', '08', '21', '17', '09', '20', '16', '22', '17', '11', '23', '11', '18', '10', '04', '20', '17', '22', '14', '09', '12', '13', '12', '11', '17', '19', '15', '10', '23', '22', '14', '10', '13', '15', '12', '16', '15', '20', '12', '14', '16', '18', '23', '09', '12', '15', '20', '12', '18', '15', '22', '14', '13', '22', '00', '06', '14', '11', '10', '12', '12', '21', '23', '00', '16', '18', '12', '19', '17', '18', '17', '03', '19', '14', '22', '23', '17', '16', '12', '09', '10', '21', '00', '18', '10', '23', '06', '22', '13', '17', '19', '19', '12', '10', '11', '11', '18', '08', '20', '14', '15', '21', '22', '22', '17', '09', '23', '10', '18', '11', '13', '19', '21', '00', '08', '21', '18', '22', '18', '09', '03', '08', '10', '20', '01', '13', '15', '00', '22', '00', '12', '17', '10', '14', '20', '21', '20', '11', '17', '14', '21', '07', '23', '10', '11', '01', '14', '14', '17', '23', '00', '23', '14', '14', '13', '16', '20', '16', '17', '23', '13', '12', '23', '21', '23', '14', '18', '13', '20', '15', '12', '22', '12', '09', '11', '16', '19', '22', '16', '19', '09', '10', '17', '17', '22', '21', '15', '22', '12', '23', '20', '08', '19', '21', '14', '17', '20', '10', '09', '21', '11', '09', '18', '21', '12', '09', '21', '14', '02', '12', '23', '21', '00', '13', '18', '15', '12', '08', '19', '09', '08', '09', '20', '10', '02', '03', '21', '23', '15', '15', '17', '09', '16', '07', '21', '21', '10', '16', '16', '21', '10', '12', '17', '00', '13', '22', '21', '21', '09', '20', '15', '14', '22', '01', '20', '11', '13', '12', '14', '19', '16', '21', '14', '23', '16', '20', '02', '12', '19', '10', '18', '20', '18', '10', '20', '08', '18', '02', '09', '19', '16', '22', '03', '19', '09', '09', '20', '23', '03', '15', '16', '16', '13', '13', '12', '12', '19', '14', '20', '20', '23', '18', '11', '20', '15', '16', '12', '16', '13', '10', '23', '17', '15', '08', '17', '21', '15', '20', '20', '21', '22', '22', '22', '20', '21', '22', '00', '12', '17', '14', '17', '15', '09', '15', '20', '13', '20', '00', '12', '08', '19', '10', '08', '11', '14', '11', '00', '22', '00', '15', '13', '16', '21', '15', '15', '21', '19', '16', '19', '11', '21', '16', '15', '15', '17', '20', '09', '10', '21', '10', '18', '17', '15', '21', '22', '21', '14', '10', '16', '17', '18', '16', '23', '07', '17', '17', '06', '15', '20', '20', '21 ...

# %%
import random
from pyecharts import Bar
attr = ["{}时".format(i) for i in range(24)]
v1 = [hourList.count(str(_).rjust(2,'0')) for _ in range(24)]
bar = Bar("手机购买时段",title_color='#FF0000',background_color='#7EC0EE')
bar.add("", attr, v1, is_label_show=True, is_datazoom_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="32378de9c0ef43269ff6ef395a827b3c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_32378de9c0ef43269ff6ef395a827b3c = echarts.init(document.getElementById('32378de9c0ef43269ff6ef395a827b3c'), 'light', {renderer: 'canvas'});
#
# var option_32378de9c0ef43269ff6ef395a827b3c = {
#     "series_id": 2354314,
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "animation": true,
#     "toolbox": {
#         "show": true,
#         "left": "95%",
#         "orient": "vertical",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#FF0000"
#             },
#             "text": "\u624b\u673a\u8d2d\u4e70\u65f6\u6bb5",
#             "top": "auto",
#             "left": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "left": "center",
#             "top": "top",
#             "show": true,
#             "orient": "horizontal",
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple"
#         }
#     ],
#     "backgroundColor": "#7EC0EE",
#     "yAxis": [
#         {
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value",
#             "inverse": false,
#             "nameGap": 25,
#             "show": true,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "boundaryGap": true
#         }
#     ],
#     "xAxis": [
#         {
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "splitLine": {
#                 "show": false
#             },
#             "type": "category",
#             "show": true,
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameGap": 25,
#             "boundaryGap": true,
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8
#             },
#             "data": [
#                 "0\u65f6",
#                 "1\u65f6",
#                 "2\u65f6",
#                 "3\u65f6",
#                 "4\u65f6",
#                 "5\u65f6",
#                 "6\u65f6",
#                 "7\u65f6",
#                 "8\u65f6",
#                 "9\u65f6",
#                 "10\u65f6",
#                 "11\u65f6",
#                 "12\u65f6",
#                 "13\u65f6",
#                 "14\u65f6",
#                 "15\u65f6",
#                 "16\u65f6",
#                 "17\u65f6",
#                 "18\u65f6",
#                 "19\u65f6",
#                 "20\u65f6",
#                 "21\u65f6",
#                 "22\u65f6",
#                 "23\u65f6"
#             ]
#         }
#     ],
#     "series": [
#         {
#             "seriesId": 2354314,
#             "barCategoryGap": "20%",
#             "type": "bar",
#             "markLine": {
#                 "data": []
#             },
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 540,
#                 272,
#                 120,
#                 115,
#                 68,
#                 68,
#                 144,
#                 384,
#                 762,
#                 1207,
#                 1585,
#                 1431,
#                 1378,
#                 1229,
#                 1173,
#                 1415,
#                 1129,
#                 1268,
#                 1130,
#                 1132,
#                 1415,
#                 1404,
#                 1380,
#                 967
#             ],
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "dataZoom": [
#         {
#             "start": 50,
#             "show": true,
#             "orient": "horizontal",
#             "end": 100,
#             "type": "slider"
#         }
#     ]
# };
# myChart_32378de9c0ef43269ff6ef395a827b3c.setOption(option_32378de9c0ef43269ff6ef395a827b3c);
#
#     });
# </script>

# %% [markdown]
# 分析一天中不同时段消费者的手机购买情况，可以分析得出，大部分消费者在午时（10-12时）和晚上（20-22时）出现了消费高峰期，在此时段顾客购买商品的概率更大，他们浏览商品的机会更多

# %%
import numpy as np

v = [[]]
for level in level_encoder.classes_:
    print(level)
    df = Comment_data[Comment_data['会员级别'] == level]
    hourList = []
    month = []
    for i in df['购买时间']:
        try:
            #print(str(i).split(' ')[0].split('-')[1])
            month.append(str(i).split(' ')[0].split('-')[1])
        except:
            useLessData += 1
    print(useLessData)
    data = []
    for _ in range(1, 13):
        if(_ < 10):
            data.append(month.count('0'+str(_)))
        else:
            data.append(month.count(str(_)))
    #print(data)
    v.append(data)
print(v)
# Out:
# PLUS会员
# 0
# PLUS会员[试用]
# 0
# 企业会员
# 0
# 注册会员
# 0
# 金牌会员
# 0
# 钻石会员
# 0
# 铜牌会员
# 0
# 银牌会员
# 0
# [[], [771, 1045, 993, 256, 292, 396, 252, 304, 232, 372, 1404, 404], [16, 163, 87, 4, 4, 0, 4, 4, 8, 4, 24, 0], [76, 28, 4, 0, 4, 0, 4, 0, 0, 8, 4, 24], [368, 582, 260, 0, 0, 0, 0, 0, 0, 0, 0, 20], [600, 661, 663, 224, 228, 352, 208, 196, 204, 228, 912, 276], [392, 478, 358, 136, 156, 272, 140, 116, 104, 268, 784, 220], [301, 546, 256, 0, 0, 0, 0, 0, 0, 0, 0, 8], [709, 850, 581, 176, 136, 300, 224, 212, 156, 124, 384, 156]]

# %%
from pyecharts import Line
import numpy as np

attr = ["一月", "二月", "三月", "四月", "五月", "六月",'七月','八月','九月','十月','十一月','十二月']
#plus = Comment_data[Comment_data['会员级别']=='PLUS会员']
#v1 = [month.count(str(_)) for _ in range(0, 12)]
#v2 = [55, 60, 16, 20, 15, 80]
line = Line("月消费与会员等级分析",title_color='#20B2AA',background_color='#F0F8FF')
count = 1
saleSum = 0.0
for level in level_encoder.classes_:
    line.add(level, attr, v[count], mark_point=["average"], legend_pos ='right',legend_top ='7%')
    saleSum += np.mean(v[count])
    count += 1
count = 1
for level in level_encoder.classes_:
    print("%s所占比例%.2lf%%"%(level, np.mean(v[count])*100 / saleSum))
    count += 1
    
#line.add("PLUS会员", attr, v1, mark_point=["average"])

#line.add("商家B", attr, v2, is_smooth=True, mark_line=["max", "average"])
line
# Out:
# PLUS会员所占比例30.95%
# PLUS会员[试用]所占比例1.46%
# 企业会员所占比例0.70%
# 注册会员所占比例5.66%
# 金牌会员所占比例21.88%
# 钻石会员所占比例15.77%
# 铜牌会员所占比例5.12%
# 银牌会员所占比例18.46%
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="fe57cc2f037441ff95e944fc17df0721" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_fe57cc2f037441ff95e944fc17df0721 = echarts.init(document.getElementById('fe57cc2f037441ff95e944fc17df0721'), 'light', {renderer: 'canvas'});
#
# var option_fe57cc2f037441ff95e944fc17df0721 = {
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "series_id": 379299,
#     "yAxis": [
#         {
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value",
#             "inverse": false,
#             "nameGap": 25,
#             "show": true,
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "boundaryGap": true
#         }
#     ],
#     "series": [
#         {
#             "seriesId": 379299,
#             "type": "line",
#             "markLine": {
#                 "data": []
#             },
#             "symbol": "emptyCircle",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "showSymbol": true,
#             "smooth": false,
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "curveness": 0,
#                     "opacity": 1,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "symbolSize": 4,
#             "markPoint": {
#                 "data": [
#                     {
#                         "symbol": "pin",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbolSize": 50,
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ]
#             },
#             "name": "PLUS\u4f1a\u5458",
#             "step": false,
#             "data": [
#                 [
#                     "\u4e00\u6708",
#                     771
#                 ],
#                 [
#                     "\u4e8c\u6708",
#                     1045
#                 ],
#                 [
#                     "\u4e09\u6708",
#                     993
#                 ],
#                 [
#                     "\u56db\u6708",
#                     256
#                 ],
#                 [
#                     "\u4e94\u6708",
#                     292
#                 ],
#                 [
#                     "\u516d\u6708",
#                     396
#                 ],
#                 [
#                     "\u4e03\u6708",
#                     252
#                 ],
#                 [
#                     "\u516b\u6708",
#                     304
#                 ],
#                 [
#                     "\u4e5d\u6708",
#                     232
#                 ],
#                 [
#                     "\u5341\u6708",
#                     372
#                 ],
#                 [
#                     "\u5341\u4e00\u6708",
#                     1404
#                 ],
#                 [
#                     "\u5341\u4e8c\u6708",
#                     404
#                 ]
#             ]
#         },
#         {
#             "seriesId": 379299,
#             "type": "line",
#             "markLine": {
#                 "data": []
#             },
#             "symbol": "emptyCircle",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "showSymbol": true,
#             "smooth": false,
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "curveness": 0,
#                     "opacity": 1,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "symbolSize": 4,
#             "markPoint": {
#                 "data": [
#                     {
#                         "symbol": "pin",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbolSize": 50,
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ]
#             },
#             "name": "PLUS\u4f1a\u5458[\u8bd5\u7528]",
#             "step": false,
#             "data": [
#                 [
#                     "\u4e00\u6708",
#                     16
#                 ],
#                 [
#                     "\u4e8c\u6708",
#                     163
#                 ],
#                 [
#                     "\u4e09\u6708",
#                     87
#                 ],
#                 [
#                     "\u56db\u6708",
#                     4
#                 ],
#                 [
#                     "\u4e94\u6708",
#                     4
#                 ],
#                 [
#                     "\u516d\u6708",
#                     0
#                 ],
#                 [
#                     "\u4e03\u6708",
#                     4
#                 ],
#                 [
#                     "\u516b\u6708",
#                     4
#                 ],
#                 [
#                     "\u4e5d\u6708",
#                     8
#                 ],
#                 [
#                     "\u5341\u6708",
#                     4
#                 ],
#                 [
#                     "\u5341\u4e00\u6708",
#                     24
#                 ],
#                 [
#                     "\u5341\u4e8c\u6708",
#                     0
#                 ]
#             ]
#         },
#         {
#             "seriesId": 379299,
#             "type": "line",
#             "markLine": {
#                 "data": []
#             },
#             "symbol": "emptyCircle",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },

# %% [markdown]
# 通过分析上图可知，不论是哪种会员，他们在三月份前后以及十二月份前后购买手机的可能性最大，这可能大家新的一年想换一个新手机的想法有关，在这些月份进行手机推荐可能会有不错的收获。并且分析不同会员的购买情况可知，他们购买的频次降序排列为PLUS会员》金牌会员》银牌会员=钻石会员》PLUS会员（试用）》企业会员。
# 分析原因，大致是因为PLUS会员大部分都属于高消费群体，他们购买这些价值昂贵的手机概率更大。因此，大致可以推断，这款手机的主要消费对象是京东商城的PLUS会员（31.00%）、金牌会员（21.87%）、银牌会员（18.52%）。

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
 
data = Comment_data['评论内容'].tolist()
dataStr = ','.join(data)
#print(','.join(data))

# %% [markdown]
# 注:此处可能因评论数据量太大，出现数据溢出问题，解决方案参照[处理Jupyter Notebook报错：IOPub data rate exceeded](https://blog.csdn.net/LaoChengZier/article/details/80705298)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
 
backgroup_Image = plt.imread('phone.jpg') #笼罩图
 
#f = open('人工智能.txt','r').read()  #生成词云的文档
wordcloud = WordCloud(
        background_color = 'white', #背景颜色，根据图片背景设置，默认为黑色
        mask = backgroup_Image, #笼罩图
        font_path = 'C:\Windows\Fonts\STZHONGS.TTF',#若有中文需要设置才会显示中文
        width = 1000,
        height = 1200,
        margin = 2).generate(dataStr) # generate 可以对全部文本进行自动分词
#参数 width，height，margin分别对应宽度像素，长度像素，边缘空白处
 
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
 
#保存图片：默认为此代码保存的路径
wordcloud.to_file('phoneComment.jpg')

# %% [markdown]
# 从图中可以看出，存在一些无效数据，没有处理，比如hellip就是无效数据。并且标点符号的影响使得一些评论次数比较多的句子
# 显示了出来，这显然不太符合预期的词图效果。
# 下面去在去除一些冗余的数据之后，重新进行分词并生存词云

# %%
dataStr = dataStr.replace('hellip','')
dataStr = dataStr.replace('。','')
dataStr = dataStr.replace('，','').replace('！','').replace(',','').replace('&','').replace('...','')

# %%
# -*- coding: utf-8 -*-
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import jieba
import os
backgroup_Image = plt.imread('picture/phone.jpg') #笼罩图
wordlist = jieba.cut(dataStr, cut_all=False)
word_string = " ".join(wordlist)
wordcloud = WordCloud(font_path='front/simsun.ttc', background_color="white",mask = backgroup_Image, width=1000, height=860, margin=2).generate(word_string)
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
wordcloud.to_file('picture/phoneComment.jpg')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.980 seconds.
# Prefix dict has been built succesfully.

# %% [markdown]
# 通过上面此图基本可以看出消费者对该款手机的整体评价，但其中可能还有一些刷单的情况，这些量无法控制，没法排除，因此还是要理性的看待一款手机综合性能。

# %%
from pyecharts import Pie
from pyecharts import Timeline
#attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
attr = phone_type
year1 = []
year2 = []
year3 = []
Comment_data['购买时间'] = Comment_data['购买时间'].map(lambda x:x.split(' ')[0].split('-')[0])
#print(Comment_data)
#year1 = Comment_data[Comment_data['手机型号']==typ
data1 = Comment_data[Comment_data['购买时间'] == '2017']
data2 = Comment_data[Comment_data['购买时间'] == '2018']
data3 = Comment_data[Comment_data['购买时间'] == '2019']
#res = pd.concat([df1,df2,df3],axis=0,ignore_index=True)
#data = Comment_data[Comment_data['手机型号']=='Apple iPhone 8 Plus 256GB 红色特别版 移动联通电信4G手机']
v1 = [len(data1[data1['手机型号']==typ]) for typ in phone_type]
v2 = [len(data2[data2['手机型号']==typ]) for typ in phone_type]
v3 = [len(data3[data3['手机型号']==typ]) for typ in phone_type]
#print(v1)
#v2 = [len(Comment_data[Comment_data['手机型号']==typ]& Comment_data['购买时间'] == '2018') for typ in phone_type]
#v3 = [len(Comment_data[Comment_data['手机型号']==typ]& Comment_data['购买时间'] == '2019') for typ in phone_type]
#print(v1)
pie_1 = Pie("2017 年手机售出情况", title_pos='center',background_color='#F0F8FF')
pie_1.add("",attr,v1,radius=[40, 75],label_text_color=None,is_label_show=True,legend_orient="vertical",legend_pos="left",is_legend_show=False)
pie_2 = Pie("2018 年手机售出情况", title_pos='center',background_color='#F0F8FF')
pie_2.add("",attr,v2,radius=[40, 75],label_text_color=None,is_label_show=True,legend_orient="vertical",legend_pos="left",is_legend_show=False)
pie_3 = Pie("2019 年手机售出情况", title_pos='center',background_color='#F0F8FF')
pie_3.add("",attr,v3,radius=[40, 75],label_text_color=None,is_label_show=True,legend_orient="vertical",legend_pos="left",is_legend_show=False)
timeline = Timeline(is_auto_play=True, timeline_bottom=0)
timeline.add(pie_1, '2017 年')
timeline.add(pie_2, '2018 年')
timeline.add(pie_3, '2019 年')
timeline
#
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="9b777a3884974d2496e151644b3d9fd9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_9b777a3884974d2496e151644b3d9fd9 = echarts.init(document.getElementById('9b777a3884974d2496e151644b3d9fd9'), 'light', {renderer: 'canvas'});
#
# var option_9b777a3884974d2496e151644b3d9fd9 = {
#     "baseOption": {
#         "timeline": {
#             "axisType": "category",
#             "rewind": false,
#             "left": "auto",
#             "top": "auto",
#             "playInterval": 2000,
#             "right": "auto",
#             "autoPlay": true,
#             "symbolSize": 10,
#             "bottom": 0,
#             "symbol": "emptyCircle",
#             "show": true,
#             "data": [
#                 "2017 \u5e74",
#                 "2018 \u5e74",
#                 "2019 \u5e74"
#             ],
#             "loop": true
#         },
#         "backgroundColor": "#F0F8FF",
#         "series": []
#     },
#     "options": [
#         {
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597",
#                 "#f6f5ec"
#             ],
#             "title": [
#                 {
#                     "top": "auto",
#                     "left": "center",
#                     "textStyle": {
#                         "fontSize": 18
#                     },
#                     "text": "2017 \u5e74\u624b\u673a\u552e\u51fa\u60c5\u51b5",
#                     "subtextStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             ],
#             "legend": [
#                 {
#                     "selectedMode": "multiple",
#                     "left": "left",
#                     "orient": "vertical",
#                     "top": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "data": [
#                         "Apple iPhone 8 Plus (A1864) 256GB \u91d1\u8272 \u79fb\u52a8\u8054\u901a\u7535\u4fe14G\u624b\u673a",
#                         "Apple iPhone 8 Plus (A1864) 256GB \u94f6\u8272 \u79fb\u52a8\u8054\u901a\u7535\u4fe14G\u624b\u673a",
#                         "Apple iPhone 8 Plus (A1864) 64GB \u6df1\u7a7a\u7070\u8272 \u79fb\u52a8\u8054\u901a\u7535\u4fe14G\u624b\u673a",
#                         "Apple iPhone 8 Plus 256GB \u7ea2\u8272\u7279\u522b\u7248 \u79fb\u52a8\u8054\u901a\u7535\u4fe14G\u624b\u673a"
#                     ]
#                 }
#             ],
#             "tooltip": {
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "borderColor": "#333",
#                 "backgroundColor": "rgba(50,50,50,0.7)",
#                 "borderWidth": 0,
#                 "triggerOn": "mousemove|click",
#                 "trigger": "item",
#                 "textStyle": {
#                     "fontSize": 14
#                 }
#             },
#             "series": [
#                 {
#                     "seriesId": 4773243,
#                     "radius": [
#                         "40%",
#                         "75%"
#                     ],
#                     "label": {
#                         "normal": {
#                             "show": true,
#                             "position": "outside",
#                             "textStyle": {
#                                 "fontSize": 12
#                             },
#                             "formatter": "{b}: {d}%"
#                         },
#                         "emphasis": {
#                             "show": true,
#                             "textStyle": {
#                                 "fontSize": 12
#                             },
#                             "formatter": "{b}: {d}%"
#                         }
#                     },
#                     "center": [
#                         "50%",
#                         "50%"
#                     ],
#                     "data": [
#                         {
#                             "value": 1071,
#                             "name": "Apple iPhone 8 Plus (A1864) 256GB \u91d1\u8272 \u79fb\u52a8\u8054\u901a\u7535\u4fe14G\u624b\u673a"
#                         },
#                         {
#                             "value": 1071,
#                             "name": "Apple iPhone 8 Plus (A1864) 256GB \u94f6\u8272 \u79fb\u52a8\u8054\u901a\u7535\u4fe14G\u624b\u673a"
#                         },
#                         {
#                             "value": 1071,
#                             "name": "Apple iPhone 8 Plus (A1864) 64GB \u6df1\u7a7a\u7070\u8272 \u79fb\u52a8\u8054\u901a\u7535\u4fe14G\u624b\u673a"
#                         },
#                         {
#                             "value": 1071,
#                             "name": "Apple iPhone 8 Plus 256GB \u7ea2\u8272\u7279\u522b\u7248 \u79fb\u52a8\u8054\u901a\u7535\u4fe14G\u624b\u673a"
#                         }
#                     ],
#                     "type": "pie"
#                 }
#             ]
#         },
#         {
#             "color": [
#                 "#c23531",
#                 "#2f4554",
#                 "#61a0a8",
#                 "#d48265",
#                 "#749f83",
#                 "#ca8622",
#                 "#bda29a",
#                 "#6e7074",
#                 "#546570",
#                 "#c4ccd3",
#                 "#f05b72",
#                 "#ef5b9c",
#                 "#f47920",
#                 "#905a3d",
#                 "#fab27b",
#                 "#2a5caa",
#                 "#444693",
#                 "#726930",
#                 "#b2d235",
#                 "#6d8346",
#                 "#ac6767",
#                 "#1d953f",
#                 "#6950a1",
#                 "#918597",
#                 "#f6f5ec"
#             ],
#             "title": [
#                 {
#                     "top": "auto",
#                     "left": "center",
#                     "textStyle": {
#                         "fontSize": 18
#                     },
#                     "text": "2018 \u5e74\u624b\u673a\u552e\u51fa\u60c5\u51b5",
#                     "subtextStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             ],
#             "legend": [
#                 {
#                     "selectedMode": "multiple",
#                     "left": "left",
#                     "orient": "vertical",
#                     "top": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "data": [
#                         "Apple iPhone 8 Plus (A1864) 256GB \u91d1\u8272 \u79fb\u52a8\u8054\u901a\u7535\u4fe14G\u624b\u673a",
#                         "Apple iPhone 8 Plus (A1864) 256GB \u94f6\u8272 \u79fb\u52a8\u8054\u901a\u7535\u4fe14G\u624b\u673a",
#                         "Apple iPhone 8 Plus (A1864) 64GB \u6df1\u7a7a\u7070\u8272 \u79fb\u52a8\u8054\u901a\u7535\u4fe14G\u624b\u673a",
#                         "Apple iPhone 8 Plus 256GB \u7ea2\u8272\u7279\u522b\u7248 \u79fb\u52a8\u8054\u901a\u7535\u4fe14G\u624b\u673a"
#                     ]
#                 }
#             ],
#             "tooltip": {
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "borderColor": "#333",
#                 "backgroundColor": "rgba(50,50,50,0.7)",
#                 "borderWidth": 0,
